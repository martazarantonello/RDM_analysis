# %% [markdown]
# This notebook is meant to analyze the reference stations file to clean it and provide corrected reference files.
# AIM:
# - keep all entries, even signals etc. as they could be included as incident locations.
# - remove duplicate entries of DfT categories, and therefore of the data that will be analyzed and saved into 'processed data'
#
# -> As of 31 March 2024, there were 2,585 open mainline stations in Great Britain

# %%
import pandas as pd

# Load the two reference files
stations_coords = pd.read_json('../data/reference provided/stations_ref_coordinates.json')
stations_dft = pd.read_json('../data/reference provided/stations_ref_with_dft.json')

print("Columns in stations_ref_coordinates.json:")
print(stations_coords.columns.tolist())
print(f"\nShape: {stations_coords.shape}")
print(f"\nTotal stanox entries: {len(stations_coords)}")

print("\n" + "="*50)
print("\nColumns in stations_ref_with_dft.json:")
print(stations_dft.columns.tolist())
print(f"\nShape: {stations_dft.shape}")
print(f"\nTotal stanox entries: {len(stations_dft)}")
# Out:
# Columns in stations_ref_coordinates.json:
# ['location_id', 'name', 'description', 'tiploc', 'crs', 'nlc', 'stanox', 'notes', 'longitude', 'latitude', 'isOffNetwork', 'timingPointType']
#
# Shape: (54386, 12)
#
# Total stanox entries: 54386
#
# ==================================================
#
# Columns in stations_ref_with_dft.json:
# ['location_id', 'name', 'description', 'tiploc', 'crs', 'nlc', 'stanox', 'notes', 'longitude', 'latitude', 'isOffNetwork', 'timingPointType', 'dft_category']
#
# Shape: (4317, 13)
#
# Total stanox entries: 4317

# %% [markdown]
# ## Extract TIPLOCs from Schedule Data
#
# Now we'll load the schedule data and extract all unique TIPLOCs that are actually used in the schedules. This will help us filter the reference file to keep only relevant entries.

# %%
# Load the schedule data
import pickle

schedule_file = '../data/CIF_ALL_FULL_DAILY_toc-full_p4.pkl'
print(f"Loading schedule data from: {schedule_file}")
schedule_data = pd.read_pickle(schedule_file)
print(f"Loaded {len(schedule_data)} schedule entries")
print(f"Type: {type(schedule_data)}")
# Out:
# Loading schedule data from: ../data/CIF_ALL_FULL_DAILY_toc-full_p4.pkl
# Loaded 680185 schedule entries
# Type: <class 'pandas.core.frame.DataFrame'>
# Loaded 680185 schedule entries
# Type: <class 'pandas.core.frame.DataFrame'>

# %%
# Extract all unique TIPLOCs from schedule data
all_tiplocs = set()

# If it's a DataFrame, convert to list of dicts
if isinstance(schedule_data, pd.DataFrame):
    schedule_list = schedule_data.to_dict('records')
else:
    schedule_list = schedule_data

print("Extracting TIPLOCs from schedule entries...")
for idx, entry in enumerate(schedule_list):
    if idx % 10000 == 0:
        print(f"  Processed {idx}/{len(schedule_list)} entries, found {len(all_tiplocs)} unique TIPLOCs")
    
    try:
        # Navigate to schedule_segment -> schedule_location
        schedule_locations = entry['schedule_segment']['schedule_location']
        
        # Extract all tiploc_code values from this schedule
        for loc in schedule_locations:
            tiploc = loc.get('tiploc_code')
            if tiploc:
                all_tiplocs.add(tiploc)
    except (KeyError, TypeError):
        continue

print(f"\nTotal unique TIPLOCs found in schedule data: {len(all_tiplocs)}")
print(f"Sample TIPLOCs: {list(all_tiplocs)[:10]}")
# Out:
# Extracting TIPLOCs from schedule entries...
#   Processed 0/680185 entries, found 0 unique TIPLOCs
#   Processed 10000/680185 entries, found 3712 unique TIPLOCs
#   Processed 20000/680185 entries, found 4683 unique TIPLOCs
#   Processed 30000/680185 entries, found 5438 unique TIPLOCs
#   Processed 20000/680185 entries, found 4683 unique TIPLOCs
#   Processed 30000/680185 entries, found 5438 unique TIPLOCs
#   Processed 40000/680185 entries, found 5662 unique TIPLOCs
#   Processed 40000/680185 entries, found 5662 unique TIPLOCs
#   Processed 50000/680185 entries, found 5891 unique TIPLOCs
#   Processed 50000/680185 entries, found 5891 unique TIPLOCs
#   Processed 60000/680185 entries, found 5924 unique TIPLOCs
#   Processed 60000/680185 entries, found 5924 unique TIPLOCs
#   Processed 70000/680185 entries, found 5940 unique TIPLOCs
#   Processed 80000/680185 entries, found 6200 unique TIPLOCs
#   Processed 70000/680185 entries, found 5940 unique TIPLOCs
#   Processed 80000/680185 entries, found 6200 unique TIPLOCs
#   Processed 90000/680185 entries, found 6240 unique TIPLOCs
#   Processed 90000/680185 entries, found 6240 unique TIPLOCs
#   Processed 100000/680185 entries, found 6384 unique TIPLOCs
#   Processed 110000/680185 entries, found 6403 unique TIPLOCs
#   Processed 100000/680185 entries, found 6384 unique TIPLOCs
#   Processed 110000/680185 entries, found 6403 unique TIPLOCs
#   Processed 120000/680185 entries, found 6482 unique TIPLOCs
#   Processed 130000/680185 entries, found 6538 unique TIPLOCs
#   Processed 140000/680185 entries, found 6548 unique TIPLOCs
#   Processed 120000/680185 entries, found 6482 unique TIPLOCs
#   Processed 130000/680185 entries, found 6538 unique TIPLOCs
#   Processed 140000/680185 entries, found 6548 unique TIPLOCs
#   Processed 150000/680185 entries, found 6597 unique TIPLOCs
#   Processed 160000/680185 entries, found 6633 unique TIPLOCs
#   Processed 150000/680185 entries, found 6597 unique TIPLOCs
#   Processed 160000/680185 entries, found 6633 unique TIPLOCs
#   Processed 170000/680185 entries, found 6646 unique TIPLOCs
#   Processed 170000/680185 entries, found 6646 unique TIPLOCs
#   Processed 180000/680185 entries, found 6687 unique TIPLOCs
#   Processed 190000/680185 entries, found 6693 unique TIPLOCs
#   Processed 180000/680185 entries, found 6687 unique TIPLOCs
#   Processed 190000/680185 entries, found 6693 unique TIPLOCs
#   Processed 200000/680185 entries, found 6707 unique TIPLOCs
#   Processed 200000/680185 entries, found 6707 unique TIPLOCs
#   Processed 210000/680185 entries, found 6732 unique TIPLOCs
#   Processed 210000/680185 entries, found 6732 unique TIPLOCs
#   Processed 220000/680185 entries, found 6744 unique TIPLOCs
#   Processed 230000/680185 entries, found 6762 unique TIPLOCs
#   Processed 220000/680185 entries, found 6744 unique TIPLOCs
#   Processed 230000/680185 entries, found 6762 unique TIPLOCs
#   Processed 240000/680185 entries, found 6765 unique TIPLOCs
#   Processed 240000/680185 entries, found 6765 unique TIPLOCs
#   Processed 250000/680185 entries, found 6778 unique TIPLOCs
#   Processed 250000/680185 entries, found 6778 unique TIPLOCs
#   Processed 260000/680185 entries, found 6781 unique TIPLOCs
#   Processed 270000/680185 entries, found 6811 unique TIPLOCs
#   Processed 260000/680185 entries, found 6781 unique TIPLOCs
#   Processed 270000/680185 entries, found 6811 unique TIPLOCs
#   Processed 280000/680185 entries, found 6812 unique TIPLOCs
#   Processed 290000/680185 entries, found 6826 unique TIPLOCs
#   Processed 280000/680185 entries, found 6812 unique TIPLOCs
#   Processed 290000/680185 entries, found 6826 unique TIPLOCs
#   Processed 300000/680185 entries, found 6835 unique TIPLOCs
#   Processed 300000/680185 entries, found 6835 unique TIPLOCs
#   Processed 310000/680185 entries, found 6836 unique TIPLOCs
#   Processed 320000/680185 entries, found 6836 unique TIPLOCs
#   Processed 310000/680185 entries, found 6836 unique TIPLOCs
#   Processed 320000/680185 entries, found 6836 unique TIPLOCs
#   Processed 330000/680185 entries, found 6842 unique TIPLOCs
#   Processed 340000/680185 entries, found 6842 unique TIPLOCs
#   Processed 350000/680185 entries, found 6845 unique TIPLOCs
#   Processed 330000/680185 entries, found 6842 unique TIPLOCs
#   Processed 340000/680185 entries, found 6842 unique TIPLOCs
#   Processed 350000/680185 entries, found 6845 unique TIPLOCs
#   Processed 360000/680185 entries, found 6847 unique TIPLOCs
#   Processed 370000/680185 entries, found 6847 unique TIPLOCs
#   Processed 380000/680185 entries, found 6850 unique TIPLOCs
#   Processed 390000/680185 entries, found 6854 unique TIPLOCs
#   Processed 360000/680185 entries, found 6847 unique TIPLOCs
#   Processed 370000/680185 entries, found 6847 unique TIPLOCs
#   Processed 380000/680185 entries, found 6850 unique TIPLOCs
#   Processed 390000/680185 entries, found 6854 unique TIPLOCs
#   Processed 400000/680185 entries, found 6856 unique TIPLOCs
#   Processed 410000/680185 entries, found 6858 unique TIPLOCs
#   Processed 400000/680185 entries, found 6856 unique TIPLOCs
#   Processed 410000/680185 entries, found 6858 unique TIPLOCs
#   Processed 420000/680185 entries, found 6858 unique TIPLOCs
#   Processed 420000/680185 entries, found 6858 unique TIPLOCs
#   Processed 430000/680185 entries, found 6858 unique TIPLOCs
#   Processed 430000/680185 entries, found 6858 unique TIPLOCs
#   Processed 440000/680185 entries, found 6861 unique TIPLOCs
#   Processed 450000/680185 entries, found 6862 unique TIPLOCs
#   Processed 440000/680185 entries, found 6861 unique TIPLOCs
#   Processed 450000/680185 entries, found 6862 unique TIPLOCs
#   Processed 460000/680185 entries, found 6866 unique TIPLOCs
#   Processed 470000/680185 entries, found 6867 unique TIPLOCs
#   Processed 480000/680185 entries, found 6871 unique TIPLOCs
#   Processed 460000/680185 entries, found 6866 unique TIPLOCs
#   Processed 470000/680185 entries, found 6867 unique TIPLOCs
#   Processed 480000/680185 entries, found 6871 unique TIPLOCs
#   Processed 490000/680185 entries, found 6873 unique TIPLOCs
#   Processed 490000/680185 entries, found 6873 unique TIPLOCs
#   Processed 500000/680185 entries, found 6879 unique TIPLOCs
#   Processed 510000/680185 entries, found 6881 unique TIPLOCs
#   Processed 500000/680185 entries, found 6879 unique TIPLOCs
#   Processed 510000/680185 entries, found 6881 unique TIPLOCs
#   Processed 520000/680185 entries, found 6885 unique TIPLOCs
#   Processed 530000/680185 entries, found 6892 unique TIPLOCs
#   Processed 520000/680185 entries, found 6885 unique TIPLOCs
#   Processed 530000/680185 entries, found 6892 unique TIPLOCs
#   Processed 540000/680185 entries, found 6894 unique TIPLOCs
#   Processed 550000/680185 entries, found 6904 unique TIPLOCs
#   Processed 540000/680185 entries, found 6894 unique TIPLOCs
#   Processed 550000/680185 entries, found 6904 unique TIPLOCs
#   Processed 560000/680185 entries, found 6906 unique TIPLOCs
#   Processed 570000/680185 entries, found 6907 unique TIPLOCs
#   Processed 580000/680185 entries, found 6910 unique TIPLOCs
#   Processed 560000/680185 entries, found 6906 unique TIPLOCs
#   Processed 570000/680185 entries, found 6907 unique TIPLOCs
#   Processed 580000/680185 entries, found 6910 unique TIPLOCs
#   Processed 590000/680185 entries, found 6911 unique TIPLOCs
#   Processed 590000/680185 entries, found 6911 unique TIPLOCs
#   Processed 600000/680185 entries, found 6918 unique TIPLOCs
#   Processed 600000/680185 entries, found 6918 unique TIPLOCs
#   Processed 610000/680185 entries, found 6920 unique TIPLOCs
#   Processed 620000/680185 entries, found 6923 unique TIPLOCs
#   Processed 630000/680185 entries, found 6928 unique TIPLOCs
#   Processed 610000/680185 entries, found 6920 unique TIPLOCs
#   Processed 620000/680185 entries, found 6923 unique TIPLOCs
#   Processed 630000/680185 entries, found 6928 unique TIPLOCs
#   Processed 640000/680185 entries, found 6929 unique TIPLOCs
#   Processed 650000/680185 entries, found 6931 unique TIPLOCs
#   Processed 640000/680185 entries, found 6929 unique TIPLOCs
#   Processed 650000/680185 entries, found 6931 unique TIPLOCs
#   Processed 660000/680185 entries, found 6932 unique TIPLOCs
#   Processed 670000/680185 entries, found 6933 unique TIPLOCs
#   Processed 660000/680185 entries, found 6932 unique TIPLOCs
#   Processed 670000/680185 entries, found 6933 unique TIPLOCs
#   Processed 680000/680185 entries, found 6939 unique TIPLOCs
#
# Total unique TIPLOCs found in schedule data: 6939
# Sample TIPLOCs: ['DRHM357', 'WHYTELF', 'MDTTGBR', 'CREWECY', 'WSMARE', 'DRTWCHS', 'WYMNDLA', 'LAZKRKO', 'MRSTNGR', 'ROLSTN']
#   Processed 680000/680185 entries, found 6939 unique TIPLOCs
#
# Total unique TIPLOCs found in schedule data: 6939
# Sample TIPLOCs: ['DRHM357', 'WHYTELF', 'MDTTGBR', 'CREWECY', 'WSMARE', 'DRTWCHS', 'WYMNDLA', 'LAZKRKO', 'MRSTNGR', 'ROLSTN']

# %% [markdown]
# ## Filter Reference File by Schedule TIPLOCs
#
# Now we'll filter the reference file to keep only entries whose TIPLOCs are actually present in the schedule data.

# %%
# Filter the reference file to keep only TIPLOCs present in schedule data
print(f"Original reference file entries: {len(stations_dft)}")

# Filter to keep only entries where TIPLOC is in the schedule data
stations_dft_filtered = stations_dft[stations_dft['tiploc'].isin(all_tiplocs)].copy()

print(f"Filtered reference file entries: {len(stations_dft_filtered)}")
print(f"Removed {len(stations_dft) - len(stations_dft_filtered)} entries not found in schedule data")
# Out:
# Original reference file entries: 6104
# Filtered reference file entries: 4456
# Removed 1648 entries not found in schedule data

# %%
# Count how many times each TIPLOC appears in the schedule data
tiploc_counts = {}

print("Counting TIPLOC usage in schedule data...")
for idx, entry in enumerate(schedule_list):
    if idx % 10000 == 0:
        print(f"  Processed {idx}/{len(schedule_list)} entries")
    
    try:
        schedule_locations = entry['schedule_segment']['schedule_location']
        for loc in schedule_locations:
            tiploc = loc.get('tiploc_code')
            if tiploc:
                tiploc_counts[tiploc] = tiploc_counts.get(tiploc, 0) + 1
    except (KeyError, TypeError):
        continue

print(f"\nCalculated usage counts for {len(tiploc_counts)} TIPLOCs")
# Out:
# Counting TIPLOC usage in schedule data...
#   Processed 0/680185 entries
#   Processed 10000/680185 entries
#   Processed 20000/680185 entries
#   Processed 30000/680185 entries
#   Processed 40000/680185 entries
#   Processed 50000/680185 entries
#   Processed 60000/680185 entries
#   Processed 70000/680185 entries
#   Processed 80000/680185 entries
#   Processed 90000/680185 entries
#   Processed 100000/680185 entries
#   Processed 110000/680185 entries
#   Processed 120000/680185 entries
#   Processed 130000/680185 entries
#   Processed 140000/680185 entries
#   Processed 150000/680185 entries
#   Processed 160000/680185 entries
#   Processed 170000/680185 entries
#   Processed 180000/680185 entries
#   Processed 190000/680185 entries
#   Processed 200000/680185 entries
#   Processed 210000/680185 entries
#   Processed 220000/680185 entries
#   Processed 230000/680185 entries
#   Processed 240000/680185 entries
#   Processed 250000/680185 entries
#   Processed 260000/680185 entries
#   Processed 270000/680185 entries
#   Processed 280000/680185 entries
#   Processed 290000/680185 entries
#   Processed 300000/680185 entries
#   Processed 310000/680185 entries
#   Processed 320000/680185 entries
#   Processed 330000/680185 entries
#   Processed 340000/680185 entries
#   Processed 350000/680185 entries
#   Processed 360000/680185 entries
#   Processed 370000/680185 entries
#   Processed 380000/680185 entries
#   Processed 390000/680185 entries
#   Processed 400000/680185 entries
#   Processed 410000/680185 entries
#   Processed 420000/680185 entries
#   Processed 430000/680185 entries
#   Processed 440000/680185 entries
#   Processed 450000/680185 entries
#   Processed 460000/680185 entries
#   Processed 470000/680185 entries
#   Processed 480000/680185 entries
#   Processed 490000/680185 entries
#   Processed 500000/680185 entries
#   Processed 510000/680185 entries
#   Processed 520000/680185 entries
#   Processed 530000/680185 entries
#   Processed 540000/680185 entries
#   Processed 550000/680185 entries
#   Processed 560000/680185 entries
#   Processed 570000/680185 entries
#   Processed 580000/680185 entries
#   Processed 590000/680185 entries
#   Processed 600000/680185 entries
#   Processed 610000/680185 entries
#   Processed 620000/680185 entries
#   Processed 630000/680185 entries
#   Processed 640000/680185 entries
#   Processed 650000/680185 entries
#   Processed 660000/680185 entries
#   Processed 670000/680185 entries
#   Processed 680000/680185 entries
#
# Calculated usage counts for 6939 TIPLOCs

# %% [markdown]
# ## Add Missing Stations with DfT Categories
#
# Add stations that are missing from the original file but should be included with their proper DfT categories.

# %%
# Add missing stations with their DfT categories
print("Adding missing stations to the dataset:")
print("=" * 80)

# Define the missing stations with their DfT categories
missing_stations = [
    {
        "location_id": 34639,
        "name": None,
        "description": "London Bridge",
        "tiploc": "LNDNBDG",
        "crs": "LBG",
        "nlc": "514800",
        "stanox": "87601",
        "notes": None,
        "longitude": None,
        "latitude": None,
        "isOffNetwork": "TRUE",
        "timingPointType": "O",
        "dft_category": "A"  # Category A
    },
    {
        "location_id": 36219,
        "name": None,
        "description": "Victoria London",
        "tiploc": "VICTRIA",
        "crs": "VIC",
        "nlc": "542600",
        "stanox": "87201",
        "notes": None,
        "longitude": -0.146727421,
        "latitude": 51.47730525,
        "isOffNetwork": "FALSE",
        "timingPointType": "O",
        "dft_category": "A"  # Category A
    },
    {
        "location_id": 37481,
        "name": None,
        "description": "Waterloo London",
        "tiploc": "WATRLOO",
        "crs": "WAT",
        "nlc": "559800",
        "stanox": "87212",
        "notes": None,
        "longitude": -0.111577769,
        "latitude": 51.5019955,
        "isOffNetwork": "TRUE",
        "timingPointType": "O",
        "dft_category": "A"  # Category A
    },
    {
        "location_id": 36591,
        "name": None,
        "description": "Ashford International",
        "tiploc": "ASHFKI",
        "crs": "ASI",
        "nlc": "546600",
        "stanox": "89428",
        "notes": None,
        "longitude": -0.8750,
        "latitude": 51.1435,
        "isOffNetwork": "FALSE",
        "timingPointType": "O",
        "dft_category": "B"  # Category B
    },
    {
        "location_id": 37218,
        "name": "Ebbsfleet Int Se",
        "description": "Ebbsfleet International",
        "tiploc": "EBSFDOM",
        "crs": "EBD",
        "nlc": "556600",
        "stanox": "89530",
        "notes": None,
        "longitude": 0.319566,
        "latitude": 51.442903,
        "isOffNetwork": "FALSE",
        "timingPointType": "M",
        "dft_category": "B"  # Category B
    },
    {
        "location_id": 17058,
        "name": "St Albans",
        "description": "St Albans",
        "tiploc": "STALBCY",
        "crs": "SAC",
        "nlc": "154800",
        "stanox": "63201",
        "notes": None,
        "longitude": -0.328306197,
        "latitude": 51.74890034,
        "isOffNetwork": "FALSE",
        "timingPointType": "T",
        "dft_category": "B"  # Category B
    },
    {
        "location_id": 34752,
        "name": None,
        "description": "Waterloo (East) London",
        "tiploc": "WLOE",
        "crs": "WAE",
        "nlc": "515800",
        "stanox": "88402",
        "notes": None,
        "longitude": -0.109634505,
        "latitude": 51.50369076,
        "isOffNetwork": "FALSE",
        "timingPointType": "O",
        "dft_category": "B"  # Category B
    }
]

# First, check if Hull with CRS HUL exists and update it
hull_mask = stations_dft_corrected['crs'] == 'HUL'
if hull_mask.any():
    stations_dft_corrected.loc[hull_mask, 'dft_category'] = 'B'
    hull_desc = stations_dft_corrected.loc[hull_mask, 'description'].values[0]
    print(f"✓ Updated Hull (CRS: HUL, Description: '{hull_desc}') to category B")
else:
    print("✗ WARNING: Hull with CRS 'HUL' not found")

print()

# Add the missing stations
added_count = 0
for station in missing_stations:
    # Check if station already exists by TIPLOC or STANOX
    exists_tiploc = (stations_dft_corrected['tiploc'] == station['tiploc']).any()
    exists_stanox = (stations_dft_corrected['stanox'] == str(station['stanox'])).any()
    
    if exists_tiploc or exists_stanox:
        print(f"  Station '{station['description']}' (TIPLOC: {station['tiploc']}) already exists - updating DfT category to {station['dft_category']}")
        # Update existing entry
        mask = (stations_dft_corrected['tiploc'] == station['tiploc']) | (stations_dft_corrected['stanox'] == str(station['stanox']))
        stations_dft_corrected.loc[mask, 'dft_category'] = station['dft_category']
    else:
        # Add new entry
        new_row = pd.DataFrame([station])
        stations_dft_corrected = pd.concat([stations_dft_corrected, new_row], ignore_index=True)
        print(f"✓ Added '{station['description']}' with DfT category {station['dft_category']}")
        added_count += 1

print("\n" + "=" * 80)
print(f"Added {added_count} new stations")
print(f"Total stations in corrected dataset: {len(stations_dft_corrected)}")

# Show updated category counts
print("\nUpdated DfT Category Distribution:")
print(stations_dft_corrected['dft_category'].value_counts().sort_index())
print(f"Total with DfT category: {stations_dft_corrected['dft_category'].notna().sum()}")
print(f"Total without DfT category: {stations_dft_corrected['dft_category'].isna().sum()}")
# Out:
# Adding missing stations to the dataset:
# ================================================================================
# ✓ Updated Hull (CRS: HUL, Description: 'Hull') to category B
#
#   Station 'London Bridge' (TIPLOC: LNDNBDG) already exists - updating DfT category to A
# ✓ Added 'Victoria London' with DfT category A
#   Station 'Waterloo London' (TIPLOC: WATRLOO) already exists - updating DfT category to A
# ✓ Added 'Ashford International' with DfT category B
# ✓ Added 'Ebbsfleet International' with DfT category B
#   Station 'St Albans' (TIPLOC: STALBCY) already exists - updating DfT category to B
# ✓ Added 'Waterloo (East) London' with DfT category B
#
# ================================================================================
# Added 4 new stations
# Total stations in corrected dataset: 4321
#
# Updated DfT Category Distribution:
# dft_category
# A      21
# B      64
# C1     95
# C2    195
# Name: count, dtype: int64
# Total with DfT category: 375
# Total without DfT category: 3946

# %% [markdown]
# ## Regenerate Cleaned File with Corrections
#
# Now we'll reprocess the corrected data through the filtering and deduplication pipeline.

# %%
# Apply the complete processing pipeline to the corrected data
print("Reprocessing corrected data through filtering and deduplication pipeline...")
print("=" * 80)

# Step 1: Filter by schedule TIPLOCs
stations_dft_corrected_filtered = stations_dft_corrected[stations_dft_corrected['tiploc'].isin(all_tiplocs)].copy()
print(f"After filtering by schedule TIPLOCs: {len(stations_dft_corrected_filtered)} entries")

# Step 2: Add usage counts
stations_dft_corrected_filtered['tiploc_usage_count'] = stations_dft_corrected_filtered['tiploc'].map(tiploc_counts).fillna(0).astype(int)

# Step 3: Smart deduplication
stations_dft_corrected_filtered['has_dft_category'] = stations_dft_corrected_filtered['dft_category'].notna().astype(int)
stations_dft_corrected_filtered['priority_score'] = (
    stations_dft_corrected_filtered['has_dft_category'] * 1000000 + 
    stations_dft_corrected_filtered['tiploc_usage_count']
)

stations_dft_corrected_sorted = stations_dft_corrected_filtered.sort_values(
    by=['stanox', 'priority_score', 'tiploc'], 
    ascending=[True, False, True]
)

stations_dft_corrected_deduplicated = stations_dft_corrected_sorted.drop_duplicates(subset='stanox', keep='first')

print(f"After smart deduplication: {len(stations_dft_corrected_deduplicated)} entries")
print(f"Removed {len(stations_dft_corrected_filtered) - len(stations_dft_corrected_deduplicated)} duplicates")

# Step 4: Drop helper columns and prepare final data
columns_to_drop = ['tiploc_usage_count', 'has_dft_category', 'priority_score']
stations_final_corrected = stations_dft_corrected_deduplicated.drop(
    columns=[col for col in columns_to_drop if col in stations_dft_corrected_deduplicated.columns]
).copy()

# Step 5: Fix numeric column formatting
numeric_to_string_cols = ['nlc', 'stanox']
for col in numeric_to_string_cols:
    if col in stations_final_corrected.columns:
        stations_final_corrected[col] = stations_final_corrected[col].fillna('').apply(
            lambda x: str(int(float(x))) if x != '' and pd.notna(x) else ''
        )

print("\nFinal DfT Category Distribution (Corrected):")
print(stations_final_corrected['dft_category'].value_counts().sort_index())
print(f"Total with DfT category: {stations_final_corrected['dft_category'].notna().sum()}")
print(f"Total without DfT category: {stations_final_corrected['dft_category'].isna().sum()}")
# Out:
# Reprocessing corrected data through filtering and deduplication pipeline...
# ================================================================================
# After filtering by schedule TIPLOCs: 4319 entries
# After smart deduplication: 4319 entries
# Removed 0 duplicates
#
# Final DfT Category Distribution (Corrected):
# dft_category
# A      20
# B      63
# C1     95
# C2    195
# Name: count, dtype: int64
# Total with DfT category: 373
# Total without DfT category: 3946

# %%
# Save the final corrected and cleaned reference file
output_file_corrected = '../data/reference provided/stations_ref_with_dft_cleaned.json'

# Convert to list of dictionaries for JSON format
stations_cleaned_corrected_records = stations_final_corrected.to_dict('records')

import json
with open(output_file_corrected, 'w') as f:
    json.dump(stations_cleaned_corrected_records, f, indent=2)

print(f"Saved corrected cleaned reference file to: {output_file_corrected}")
print(f"Total entries: {len(stations_cleaned_corrected_records)}")
print(f"\nSummary:")
print(f"  - Original entries: {len(stations_dft)}")
print(f"  - After manual corrections: {len(stations_dft_corrected)}")
print(f"  - After filtering by schedule TIPLOCs: {len(stations_dft_corrected_filtered)}")
print(f"  - After smart deduplication: {len(stations_final_corrected)}")
print(f"  - Total removed: {len(stations_dft_corrected) - len(stations_final_corrected)}")
print(f"\nProcessing:")
print(f"  - Applied manual DfT category corrections")
print(f"  - Added missing stations with DfT categories")
print(f"  - Filtered by schedule TIPLOCs")
print(f"  - Smart deduplication (DfT category + usage frequency)")
print(f"  - Proper JSON formatting (nlc/stanox as strings, lat/lon as numbers)")
# Out:
# Saved corrected cleaned reference file to: ../data/reference provided/stations_ref_with_dft_cleaned.json
# Total entries: 4319
#
# Summary:
#   - Original entries: 4317
#   - After manual corrections: 4321
#   - After filtering by schedule TIPLOCs: 4319
#   - After smart deduplication: 4319
#   - Total removed: 2
#
# Processing:
#   - Applied manual DfT category corrections
#   - Added missing stations with DfT categories
#   - Filtered by schedule TIPLOCs
#   - Smart deduplication (DfT category + usage frequency)
#   - Proper JSON formatting (nlc/stanox as strings, lat/lon as numbers)

# %% [markdown]
# ## Check for TIPLOC Duplicates in Final Cleaned File
#
# Verify if there are any duplicate TIPLOCs in the final corrected cleaned file.

# %%
# Check for TIPLOC duplicates in the final cleaned file
print("Checking for TIPLOC duplicates in final cleaned file:")
print("=" * 80)

# Check for duplicate TIPLOCs
tiploc_duplicates = stations_final_corrected['tiploc'].duplicated().sum()
print(f"Number of duplicate TIPLOC entries: {tiploc_duplicates}")

if tiploc_duplicates > 0:
    # Show the duplicate TIPLOCs
    duplicate_tiplocs_df = stations_final_corrected[stations_final_corrected['tiploc'].duplicated(keep=False)].sort_values('tiploc')
    print(f"\nTotal entries with duplicate TIPLOCs: {len(duplicate_tiplocs_df)}")
    print(f"Unique TIPLOCs that are duplicated: {duplicate_tiplocs_df['tiploc'].nunique()}")
    
    print("\nDuplicate TIPLOC entries:")
    print(duplicate_tiplocs_df[['tiploc', 'stanox', 'description', 'dft_category', 'crs']].to_string())
else:
    print("\n✓ No duplicate TIPLOCs found!")
    print("Each TIPLOC appears only once in the final cleaned file.")

print("\n" + "=" * 80)
print("Summary:")
print(f"  - Total entries: {len(stations_final_corrected)}")
print(f"  - Unique TIPLOCs: {stations_final_corrected['tiploc'].nunique()}")
print(f"  - Unique STANOX: {stations_final_corrected['stanox'].nunique()}")
print(f"  - Duplicate TIPLOCs: {tiploc_duplicates}")
# Out:
# Checking for TIPLOC duplicates in final cleaned file:
# ================================================================================
# Number of duplicate TIPLOC entries: 0
#
# ✓ No duplicate TIPLOCs found!
# Each TIPLOC appears only once in the final cleaned file.
#
# ================================================================================
# Summary:
#   - Total entries: 4319
#   - Unique TIPLOCs: 4319
#   - Unique STANOX: 4319
#   - Duplicate TIPLOCs: 0

# %% [markdown]
# ## Final DfT Categories with Station Descriptions
#
# Display all stations by their DfT category in the final cleaned file.

# %%
# Display all stations by DfT category in the final cleaned file
print("FINAL DfT CATEGORY DISTRIBUTION IN CLEANED FILE")
print("=" * 100)

categories = ['A', 'B', 'C1', 'C2', 'D', 'E', 'F']

for category in categories:
    stations_in_category = stations_final_corrected[stations_final_corrected['dft_category'] == category]
    print(f"\n{'='*100}")
    print(f"DfT Category {category}: {len(stations_in_category)} stations")
    print(f"{'='*100}")
    
    if len(stations_in_category) > 0:
        # Sort by description for easier reading
        stations_sorted = stations_in_category.sort_values('description')
        
        # Display in a compact format
        for idx, row in stations_sorted.iterrows():
            name = str(row.get('description', 'N/A'))[:50]
            crs = str(row.get('crs', 'N/A'))[:4] if pd.notna(row.get('crs')) else 'N/A'
            stanox = str(row['stanox']) if pd.notna(row['stanox']) else 'N/A'
            tiploc = str(row['tiploc'])[:12] if pd.notna(row['tiploc']) else 'N/A'
            print(f"  {name:50} | CRS: {crs:4} | STANOX: {stanox:6} | TIPLOC: {tiploc:12}")
    else:
        print(f"  No stations found in category {category}")

print(f"\n{'='*100}")
print(f"\nSUMMARY:")
print(f"  Total entries in cleaned file: {len(stations_final_corrected)}")
print(f"  Stations with DfT category: {stations_final_corrected['dft_category'].notna().sum()}")
print(f"  Stations without DfT category: {stations_final_corrected['dft_category'].isna().sum()}")
print(f"\nCategory breakdown:")
for category in categories:
    count = len(stations_final_corrected[stations_final_corrected['dft_category'] == category])
    if count > 0:
        print(f"    {category}: {count}")
print(f"{'='*100}")
# Out:
# FINAL DfT CATEGORY DISTRIBUTION IN CLEANED FILE
# ====================================================================================================
#
# ====================================================================================================
# DfT Category A: 20 stations
# ====================================================================================================
#   Birmingham New Street                              | CRS: BHM  | STANOX: 65630  | TIPLOC: BHAMNWS
#   Blackfriars London                                 | CRS: BFR  | STANOX: 87245  | TIPLOC: BLFR
#   Bristol Temple Meads                               | CRS: BRI  | STANOX: 81700  | TIPLOC: BRSTLTM
#   Cannon Street London                               | CRS: CST  | STANOX: 88403  | TIPLOC: CANONST
#   Cardiff Central                                    | CRS: CDF  | STANOX: 77301  | TIPLOC: CRDFCEN
#   Charing Cross London                               | CRS: CHX  | STANOX: 88401  | TIPLOC: CHRX
#   Eastern                                            | CRS: N/A  | STANOX: 87601  | TIPLOC: LNDNBDE
#   Euston London                                      | CRS: EUS  | STANOX: 72410  | TIPLOC: EUSTON
#   Fenchurch Street London                            | CRS: FST  | STANOX: 52711  | TIPLOC: FENCHRS
#   King's Cross London                                | CRS: KGX  | STANOX: 54311  | TIPLOC: KNGX
#   Leeds                                              | CRS: LDS  | STANOX: 17132  | TIPLOC: LEEDS
#   Liverpool Lime Street                              | CRS: LIV  | STANOX: 36151  | TIPLOC: LVRPLSH
#   Liverpool Street London                            | CRS: LST  | STANOX: 52741  | TIPLOC: LIVST
#   Manchester Piccadilly                              | CRS: MAN  | STANOX: 32000  | TIPLOC: MNCRPIC
#   Marylebone London                                  | CRS: MYB  | STANOX: 63021  | TIPLOC: MARYLBN
#   Newcastle                                          | CRS: NCL  | STANOX: 12931  | TIPLOC: NWCSTLE
#   Paddington London                                  | CRS: PAD  | STANOX: 73000  | TIPLOC: PADTON
#   St Pancras London                                  | CRS: STP  | STANOX: 63630  | TIPLOC: STPX
#   Waterloo Main                                      | CRS: N/A  | STANOX: 87212  | TIPLOC: WATRLMN
#   York                                               | CRS: YRK  | STANOX: 16416  | TIPLOC: YORK
#
# ====================================================================================================
# DfT Category B: 63 stations
# ====================================================================================================
#   Ashford International                              | CRS: ASI  | STANOX: 89428  | TIPLOC: ASHFKI
#   Barking                                            | CRS: BKG  | STANOX: 51531  | TIPLOC: BARKING
#   Basingstoke                                        | CRS: BSK  | STANOX: 86066  | TIPLOC: BSNGSTK
#   Birmingham International                           | CRS: BHI  | STANOX: 69215  | TIPLOC: BHAMINT
#   Birmingham Moor Street                             | CRS: BMO  | STANOX: 66411  | TIPLOC: BHAMMRS
#   Brighton                                           | CRS: BTN  | STANOX: 87980  | TIPLOC: BRGHTN
#   Bristol Parkway                                    | CRS: BPW  | STANOX: 81109  | TIPLOC: BRSTPWY
#   Bromley South                                      | CRS: BMS  | STANOX: 88477  | TIPLOC: BROMLYS
#   Cambridge                                          | CRS: CBG  | STANOX: 47221  | TIPLOC: CAMBDGE
#   Carlisle                                           | CRS: CAR  | STANOX: 9161   | TIPLOC: CARLILE
#   Chester                                            | CRS: CTR  | STANOX: 40320  | TIPLOC: CHST
#   Clapham Junction (C)                               | CRS: N/A  | STANOX: 87219  | TIPLOC: CLPHMJC
#   Colchester                                         | CRS: COL  | STANOX: 50049  | TIPLOC: CLCHSTR
#   Coventry                                           | CRS: COV  | STANOX: 69202  | TIPLOC: COVNTRY
#   Crewe                                              | CRS: CRE  | STANOX: 42140  | TIPLOC: CREWE
#   Darlington                                         | CRS: DAR  | STANOX: 15866  | TIPLOC: DLTN
#   Derby                                              | CRS: DBY  | STANOX: 57403  | TIPLOC: DRBY
#   Didcot Parkway                                     | CRS: DID  | STANOX: 74313  | TIPLOC: DIDCOTP
#   Doncaster                                          | CRS: DON  | STANOX: 23421  | TIPLOC: DONC
#   East Croydon                                       | CRS: ECR  | STANOX: 87701  | TIPLOC: ECROYDN
#   Gatwick Airport                                    | CRS: GTW  | STANOX: 87911  | TIPLOC: GTWK
#   Guildford                                          | CRS: GLD  | STANOX: 87052  | TIPLOC: GUILDFD
#   Haywards Heath                                     | CRS: HHE  | STANOX: 87967  | TIPLOC: HYWRDSH
#   Huddersfield                                       | CRS: HUD  | STANOX: 18474  | TIPLOC: HDRSFLD
#   Hull                                               | CRS: HUL  | STANOX: 19105  | TIPLOC: HULL
#   Ipswich Signal Co.328                              | CRS: N/A  | STANOX: 49208  | TIPLOC: IPSW328
#   Lancaster                                          | CRS: LAN  | STANOX: 11720  | TIPLOC: LANCSTR
#   Leicester                                          | CRS: LEI  | STANOX: 59241  | TIPLOC: LESTER
#   Liverpool Central (Northern)                       | CRS: LVC  | STANOX: 36080  | TIPLOC: LVRPLCH
#   Liverpool Central (Wirral)                         | CRS: XLV  | STANOX: 38183  | TIPLOC: LVRPLCL
#   Liverpool South Parkway                            | CRS: LPY  | STANOX: 36091  | TIPLOC: LVRPSPY
#   Luton                                              | CRS: LUT  | STANOX: 62400  | TIPLOC: LUTON
#   Manchester Airport                                 | CRS: MIA  | STANOX: 32530  | TIPLOC: MNCRIAP
#   Manchester Victoria                                | CRS: MCV  | STANOX: 31510  | TIPLOC: MNCRVIC
#   Milton Keynes Central                              | CRS: MKC  | STANOX: 70261  | TIPLOC: MKNSCEN
#   Newport (Essex)                                    | CRS: NWE  | STANOX: 47331  | TIPLOC: NEWPRTE
#   Newport (South Wales)                              | CRS: NWP  | STANOX: 76401  | TIPLOC: NWPTRTG
#   Northwich                                          | CRS: NWI  | STANOX: 37129  | TIPLOC: NTHWICH
#   Nottingham                                         | CRS: NOT  | STANOX: 55247  | TIPLOC: NTNG
#   Oxford                                             | CRS: OXF  | STANOX: 74446  | TIPLOC: OXFD
#   Peterborough                                       | CRS: PBO  | STANOX: 45106  | TIPLOC: PBRO
#   Preston                                            | CRS: PRE  | STANOX: 30120  | TIPLOC: PRST
#   Reading                                            | CRS: RDG  | STANOX: 74237  | TIPLOC: RDNGSTN
#   Richmond                                           | CRS: RMD  | STANOX: 87135  | TIPLOC: RICHMND
#   Sevenoaks                                          | CRS: SEV  | STANOX: 89351  | TIPLOC: SVNOAKS
#   Sheffield                                          | CRS: SHF  | STANOX: 25701  | TIPLOC: SHEFFLD
#   Shenfield                                          | CRS: SNF  | STANOX: 50328  | TIPLOC: SHENFLD
#   Southampton Central                                | CRS: SOU  | STANOX: 86520  | TIPLOC: SOTON
#   St Albans                                          | CRS: SAC  | STANOX: 63201  | TIPLOC: STALBCY
#   Stansted Airport                                   | CRS: SSD  | STANOX: 47344  | TIPLOC: STANAIR
#   Stockport                                          | CRS: SPT  | STANOX: 32534  | TIPLOC: STKP
#   Stratford                                          | CRS: SRA  | STANOX: 52226  | TIPLOC: STFD
#   Surbiton                                           | CRS: SUR  | STANOX: 87171  | TIPLOC: SURBITN
#   Tonbridge                                          | CRS: TON  | STANOX: 89363  | TIPLOC: TONBDG
#   Vauxhall (Main)                                    | CRS: N/A  | STANOX: 87214  | TIPLOC: VAUXHLM
#   Wakefield Westgate                                 | CRS: WKF  | STANOX: 18067  | TIPLOC: WKFLDWG
#   Warrington Bank Quay                               | CRS: WBQ  | STANOX: 35531  | TIPLOC: WRGTNBQ
#   Waterloo (East) London                             | CRS: WAE  | STANOX: 88402  | TIPLOC: WLOE
#   Watford Junction                                   | CRS: WFJ  | STANOX: 71040  | TIPLOC: WATFDJ
#   Wigan North Western                                | CRS: WGN  | STANOX: 35136  | TIPLOC: WIGANNW
#   Wimbledon                                          | CRS: WIM  | STANOX: 87261  | TIPLOC: WIMBLDN
#   Woking                                             | CRS: WOK  | STANOX: 86031  | TIPLOC: WOKING
#   Wolverhampton                                      | CRS: WVH  | STANOX: 65043  | TIPLOC: WVRMPTN
#
# ====================================================================================================
# DfT Category C1: 95 stations
# ====================================================================================================
#   Andover                                            | CRS: ADV  | STANOX: 86074  | TIPLOC: ANDOVER
#   Banbury                                            | CRS: BAN  | STANOX: 69424  | TIPLOC: BNBR
#   Bangor (Gwynedd)                                   | CRS: BNG  | STANOX: 40036  | TIPLOC: BANGOR
#   Bath Spa                                           | CRS: BTH  | STANOX: 81501  | TIPLOC: BATHSPA
#   Belford                                            | CRS: N/A  | STANOX: 12106  | TIPLOC: BELFORD
#   Berwick-Upon-Tweed                                 | CRS: BWK  | STANOX: 12001  | TIPLOC: BRWCKUT
#   Birmingham Snow Hill                               | CRS: BSW  | STANOX: 66409  | TIPLOC: BHAMSNH
#   Blackburn                                          | CRS: BBN  | STANOX: 29150  | TIPLOC: BLKB
#   Blackpool North                                    | CRS: BPN  | STANOX: 30021  | TIPLOC: BLCKPLN
#   Blackpool South                                    | CRS: BPS  | STANOX: 30033  | TIPLOC: BLCKS
#   Bolton                                             | CRS: BON  | STANOX: 31620  | TIPLOC: BOLTON
#   Bournemouth                                        | CRS: BMH  | STANOX: 86921  | TIPLOC: BOMO
#   Bradford Interchange                               | CRS: BDI  | STANOX: 18641  | TIPLOC: BRADIN
#   Cardiff Queen Street                               | CRS: CDQ  | STANOX: 78451  | TIPLOC: CARDFQS
#   Chatham                                            | CRS: CTM  | STANOX: 89007  | TIPLOC: CHATHAM
#   Chelford                                           | CRS: CEL  | STANOX: 32583  | TIPLOC: CHELFD
#   Chelmsford                                         | CRS: CHM  | STANOX: 50223  | TIPLOC: CHLMSFD
#   Cheltenham Spa                                     | CRS: CNM  | STANOX: 68076  | TIPLOC: CHLTNHM
#   Chesterfield                                       | CRS: CHD  | STANOX: 27263  | TIPLOC: CHFD
#   Chippenham                                         | CRS: CPM  | STANOX: 75352  | TIPLOC: CHIPNHM
#   Chippenham Jn                                      | CRS: N/A  | STANOX: 46277  | TIPLOC: CHPNJN
#   City Thameslink                                    | CRS: CTK  | STANOX: 87244  | TIPLOC: CTMSLNK
#   Dartford                                           | CRS: DFD  | STANOX: 88466  | TIPLOC: DARTFD
#   Dorking                                            | CRS: DKG  | STANOX: 87687  | TIPLOC: DORKING
#   Durham                                             | CRS: DHM  | STANOX: 13702  | TIPLOC: DRHM
#   Ealing Broadway                                    | CRS: EAL  | STANOX: 73253  | TIPLOC: EALINGB
#   East Grinstead                                     | CRS: EGR  | STANOX: 87759  | TIPLOC: EGRNSTD
#   Eastbourne                                         | CRS: EBN  | STANOX: 88254  | TIPLOC: EBOURNE
#   Eastleigh                                          | CRS: ESL  | STANOX: 86087  | TIPLOC: ELGH
#   Eastleigh Hs                                       | CRS: N/A  | STANOX: 86091  | TIPLOC: ELGHHS
#   Epsom                                              | CRS: EPS  | STANOX: 87681  | TIPLOC: EPSM
#   Exeter Central                                     | CRS: EXC  | STANOX: 83431  | TIPLOC: EXETERC
#   Exeter St Davids                                   | CRS: EXD  | STANOX: 83421  | TIPLOC: EXETRSD
#   Gillingham (Dorset)                                | CRS: GIL  | STANOX: 82332  | TIPLOC: GLHM
#   Gillingham (Kent)                                  | CRS: GLM  | STANOX: 89011  | TIPLOC: GLNGHMK
#   Gloucester                                         | CRS: GCR  | STANOX: 68089  | TIPLOC: GLOSTER
#   Grantham                                           | CRS: GRA  | STANOX: 44421  | TIPLOC: GTHM
#   Greatham                                           | CRS: N/A  | STANOX: 14261  | TIPLOC: GREATHM
#   Harlow Town                                        | CRS: HWN  | STANOX: 47611  | TIPLOC: HRLWTWN
#   Harrogate                                          | CRS: HGT  | STANOX: 16102  | TIPLOC: HAGT
#   Harrow & Wealdstone                                | CRS: HRW  | STANOX: 72007  | TIPLOC: HROW
#   Harrow & Wealdstone D.C.                           | CRS: N/A  | STANOX: 72017  | TIPLOC: HROWDC
#   Hartford                                           | CRS: HTF  | STANOX: 37005  | TIPLOC: HARTFD
#   Hastings                                           | CRS: HGS  | STANOX: 88285  | TIPLOC: HASTING
#   Hereford                                           | CRS: HFD  | STANOX: 76357  | TIPLOC: HEREFRD
#   High Wycombe                                       | CRS: HWY  | STANOX: 73503  | TIPLOC: HWYCOMB
#   Leamington Spa                                     | CRS: LMS  | STANOX: 69300  | TIPLOC: LMNGTNS
#   Lincoln                                            | CRS: LCN  | STANOX: 44038  | TIPLOC: LINCLNC
#   Loughborough                                       | CRS: LBO  | STANOX: 59002  | TIPLOC: LOGHBRO
#   Macclesfield                                       | CRS: MAC  | STANOX: 32571  | TIPLOC: MACLSFD
#   Maidenhead                                         | CRS: MAI  | STANOX: 74005  | TIPLOC: MDNHEAD
#   Maidstone East                                     | CRS: MDE  | STANOX: 89403  | TIPLOC: MSTONEE
#   Maidstone West                                     | CRS: MDW  | STANOX: 89315  | TIPLOC: MSTONEW
#   Manchester Oxford Road                             | CRS: MCO  | STANOX: 33087  | TIPLOC: MNCROXR
#   Middlesbrough                                      | CRS: MBR  | STANOX: 15449  | TIPLOC: MDLSBRO
#   Narborough                                         | CRS: NBR  | STANOX: 59301  | TIPLOC: NARBRO
#   New Cross Gate London                              | CRS: NXG  | STANOX: 87603  | TIPLOC: NEWXGTE
#   Newark North Gate                                  | CRS: NNG  | STANOX: 44304  | TIPLOC: NEWANG
#   Newbury                                            | CRS: NBY  | STANOX: 74803  | TIPLOC: NEWBURY
#   Newton Abbot                                       | CRS: NTA  | STANOX: 83624  | TIPLOC: NABT
#   Northampton                                        | CRS: NMP  | STANOX: 70100  | TIPLOC: NMPTN
#   Olton                                              | CRS: OLT  | STANOX: 66461  | TIPLOC: OLTON
#   Penzance                                           | CRS: PNZ  | STANOX: 85734  | TIPLOC: PENZNCE
#   Plymouth                                           | CRS: PLY  | STANOX: 84139  | TIPLOC: PLYMTH
#   Poole                                              | CRS: POO  | STANOX: 86935  | TIPLOC: POOLE
#   Portsmouth & Southsea                              | CRS: PMS  | STANOX: 86313  | TIPLOC: PSEA
#   Portsmouth Harbour                                 | CRS: PMH  | STANOX: 86311  | TIPLOC: PHBR
#   Putney                                             | CRS: PUT  | STANOX: 87152  | TIPLOC: PUTNEY
#   Redhill                                            | CRS: RDH  | STANOX: 87722  | TIPLOC: REDHILL
#   Rugby                                              | CRS: RUG  | STANOX: 70030  | TIPLOC: RUGBY
#   Runcorn                                            | CRS: RUN  | STANOX: 36501  | TIPLOC: RUNCORN
#   Salisbury                                          | CRS: SAL  | STANOX: 86122  | TIPLOC: SLSBRY
#   Scarborough                                        | CRS: SCA  | STANOX: 16201  | TIPLOC: SCARBRO
#   Shrewsbury                                         | CRS: SHR  | STANOX: 64224  | TIPLOC: SHRWBY
#   Slough                                             | CRS: SLO  | STANOX: 73822  | TIPLOC: SLOUGH
#   Southend Central                                   | CRS: SOC  | STANOX: 51007  | TIPLOC: STHCENT
#   Southend Victoria                                  | CRS: SOV  | STANOX: 50311  | TIPLOC: STHVIC
#   Stafford                                           | CRS: STA  | STANOX: 43314  | TIPLOC: STAFFRD
#   Stamford                                           | CRS: SMD  | STANOX: 45008  | TIPLOC: STAMFD
#   Stevenage                                          | CRS: SVG  | STANOX: 53223  | TIPLOC: STEVNGE
#   Stoke-On-Trent                                     | CRS: SOT  | STANOX: 43211  | TIPLOC: STOKEOT
#   Swansea                                            | CRS: SWA  | STANOX: 79304  | TIPLOC: SWANSEA
#   Swindon                                            | CRS: SWI  | STANOX: 75012  | TIPLOC: SDON
#   Swinton                                            | CRS: SWN  | STANOX: 24108  | TIPLOC: SWINTN
#   Swinton (Greater Manchester)                       | CRS: SNN  | STANOX: 35146  | TIPLOC: SWNT
#   Taunton                                            | CRS: TAU  | STANOX: 83009  | TIPLOC: TAUNTON
#   Three Bridges                                      | CRS: TBD  | STANOX: 87920  | TIPLOC: THBDGS
#   Truro                                              | CRS: TRU  | STANOX: 85501  | TIPLOC: TRURO
#   Tunbridge Wells                                    | CRS: TBW  | STANOX: 89375  | TIPLOC: TUNWELL
#   Twickenham                                         | CRS: TWI  | STANOX: 87131  | TIPLOC: TWCKNHM
#   Twickenham Jn                                      | CRS: N/A  | STANOX: 87119  | TIPLOC: TWCKNMJ
#   Welwyn Garden City                                 | CRS: WGC  | STANOX: 53401  | TIPLOC: WLWYNGC
#   Weymouth                                           | CRS: WEY  | STANOX: 86981  | TIPLOC: WEYMTH
#   Winchester                                         | CRS: WIN  | STANOX: 86083  | TIPLOC: WNCHSTR
#   Worcester Shrub Hill                               | CRS: WOS  | STANOX: 67116  | TIPLOC: WORCSSH
#
# ====================================================================================================
# DfT Category C2: 195 stations
# ====================================================================================================
#   Abbey Wood                                         | CRS: ABW  | STANOX: 88601  | TIPLOC: ABWD
#   Aintree                                            | CRS: AIN  | STANOX: 36027  | TIPLOC: AINTREE
#   Aldershot                                          | CRS: AHT  | STANOX: 87031  | TIPLOC: ALDRSHT
#   Alton                                              | CRS: AON  | STANOX: 87021  | TIPLOC: ALTON
#   Altrincham                                         | CRS: ALT  | STANOX: 37225  | TIPLOC: ALTRNHM
#   Ascot                                              | CRS: ACT  | STANOX: 87103  | TIPLOC: ASCOT
#   Ashford (Surrey)                                   | CRS: AFS  | STANOX: 87117  | TIPLOC: ASFDMSX
#   Baildon                                            | CRS: BLD  | STANOX: 17038  | TIPLOC: BAILDON
#   Balham                                             | CRS: BAL  | STANOX: 87222  | TIPLOC: BALHAM
#   Barnehurst                                         | CRS: BNH  | STANOX: 88422  | TIPLOC: BRNHRST
#   Barnes                                             | CRS: BNS  | STANOX: 87149  | TIPLOC: BARNES
#   Barnham                                            | CRS: BAA  | STANOX: 86451  | TIPLOC: BRHM
#   Barnsley                                           | CRS: BNY  | STANOX: 24385  | TIPLOC: BNSLY
#   Basildon                                           | CRS: BSO  | STANOX: 51019  | TIPLOC: BASILDN
#   Beckenham Junction                                 | CRS: BKJ  | STANOX: 88315  | TIPLOC: BCKNHMJ
#   Benfleet                                           | CRS: BEF  | STANOX: 51014  | TIPLOC: BENFLET
#   Berkhamsted                                        | CRS: BKM  | STANOX: 70421  | TIPLOC: BERKHMD
#   Bexleyheath                                        | CRS: BXH  | STANOX: 88421  | TIPLOC: BXLYHTH
#   Billericay                                         | CRS: BIC  | STANOX: 50327  | TIPLOC: BILERCY
#   Bishops Stortford                                  | CRS: BIS  | STANOX: 47412  | TIPLOC: BSHPSFD
#   Blackheath                                         | CRS: BKH  | STANOX: 88416  | TIPLOC: BLKHTH
#   Bletchley                                          | CRS: BLY  | STANOX: 70306  | TIPLOC: BLTCHLY
#   Bracknell                                          | CRS: BCE  | STANOX: 87101  | TIPLOC: BRACKNL
#   Bradford Forster Square                            | CRS: BDQ  | STANOX: 17019  | TIPLOC: BRADFS
#   Braintree                                          | CRS: BTR  | STANOX: 50204  | TIPLOC: BRAINTR
#   Brentford                                          | CRS: BFD  | STANOX: 87144  | TIPLOC: BNTFORD
#   Brentwood                                          | CRS: BRE  | STANOX: 50331  | TIPLOC: BRTWOOD
#   Bridgend                                           | CRS: BGN  | STANOX: 79791  | TIPLOC: BRGEND
#   Brockenhurst                                       | CRS: BCU  | STANOX: 86901  | TIPLOC: BKNHRST
#   Brookwood                                          | CRS: BKO  | STANOX: 86041  | TIPLOC: BRKWOOD
#   Broxbourne                                         | CRS: BXB  | STANOX: 51722  | TIPLOC: BROXBRN
#   Broxbourne Jn                                      | CRS: N/A  | STANOX: 51720  | TIPLOC: BROXBNJ
#   Burgess Hill                                       | CRS: BUG  | STANOX: 87971  | TIPLOC: BURGESH
#   Bury St Edmunds                                    | CRS: BSE  | STANOX: 46301  | TIPLOC: BSTEDMS
#   Chadwell Heath                                     | CRS: CTH  | STANOX: 50405  | TIPLOC: CHDWLHT
#   Chalkwell                                          | CRS: CHW  | STANOX: 51011  | TIPLOC: CHLKWEL
#   Cheddington                                        | CRS: CED  | STANOX: 70319  | TIPLOC: CHDNGTN
#   Cheshunt                                           | CRS: CHN  | STANOX: 51815  | TIPLOC: CHESHNT
#   Chichester                                         | CRS: CCH  | STANOX: 86424  | TIPLOC: CHCHSTR
#   Chingford                                          | CRS: CHI  | STANOX: 52731  | TIPLOC: CHINGFD
#   Clandon                                            | CRS: CLA  | STANOX: 87069  | TIPLOC: CLANDON
#   Cromford                                           | CRS: CMF  | STANOX: 57009  | TIPLOC: CROMFD
#   Dalton                                             | CRS: DLT  | STANOX: 11271  | TIPLOC: DALTON
#   Edmonton Green                                     | CRS: EDR  | STANOX: 51949  | TIPLOC: EDMNGRN
#   Egham                                              | CRS: EGH  | STANOX: 87107  | TIPLOC: EGHAM
#   Eltham                                             | CRS: ELW  | STANOX: 88418  | TIPLOC: ELTHAM
#   Enfield Town                                       | CRS: ENF  | STANOX: 51946  | TIPLOC: ENFLDTN
#   Ewell East                                         | CRS: EWE  | STANOX: 87679  | TIPLOC: EWELLE
#   Ewell West                                         | CRS: EWW  | STANOX: 87304  | TIPLOC: EWELW
#   Fareham                                            | CRS: FRM  | STANOX: 86241  | TIPLOC: FAREHAM
#   Farnborough (Main)                                 | CRS: FNB  | STANOX: 86042  | TIPLOC: FRBRMN
#   Farnham                                            | CRS: FNH  | STANOX: 87026  | TIPLOC: FARNHAM
#   Feltham                                            | CRS: FEL  | STANOX: 87121  | TIPLOC: FELTHAM
#   Finsbury Park London                               | CRS: FPK  | STANOX: 54238  | TIPLOC: FNPK
#   Fleet                                              | CRS: FLE  | STANOX: 86045  | TIPLOC: FLEET
#   Forest Gate                                        | CRS: FOG  | STANOX: 50435  | TIPLOC: FRSTGT
#   Forest Gate Jn                                     | CRS: N/A  | STANOX: 50434  | TIPLOC: FRSTGTJ
#   Forest Hill                                        | CRS: FOH  | STANOX: 87627  | TIPLOC: FORESTH
#   Gidea Park                                         | CRS: GDP  | STANOX: 50334  | TIPLOC: GIDEAPK
#   Gidea Park Jn                                      | CRS: N/A  | STANOX: 50339  | TIPLOC: GIDEPKJ
#   Godalming                                          | CRS: GOD  | STANOX: 87057  | TIPLOC: GDLMING
#   Goodmayes                                          | CRS: GMY  | STANOX: 50412  | TIPLOC: GODMAYS
#   Grays                                              | CRS: GRY  | STANOX: 51311  | TIPLOC: GRAYS
#   Grove Park                                         | CRS: GRP  | STANOX: 88481  | TIPLOC: GRVPK
#   Hackney Downs                                      | CRS: HAC  | STANOX: 52736  | TIPLOC: HAKNYNM
#   Hadfield                                           | CRS: HDF  | STANOX: 32255  | TIPLOC: HADFILD
#   Halifax                                            | CRS: HFX  | STANOX: 18464  | TIPLOC: HLFX
#   Hampton                                            | CRS: HMP  | STANOX: 87158  | TIPLOC: HAMPTON
#   Hampton Court                                      | CRS: HMC  | STANOX: 87181  | TIPLOC: HCRT
#   Hanborough                                         | CRS: HND  | STANOX: 74451  | TIPLOC: HANDBRO
#   Hapton                                             | CRS: HPN  | STANOX: 29057  | TIPLOC: HAPTON
#   Harold Wood                                        | CRS: HRO  | STANOX: 50333  | TIPLOC: HRLDWOD
#   Haslemere                                          | CRS: HSL  | STANOX: 87062  | TIPLOC: HASLEMR
#   Hassocks                                           | CRS: HSK  | STANOX: 87973  | TIPLOC: HASOCKS
#   Hatfield                                           | CRS: HAT  | STANOX: 53501  | TIPLOC: HATFILD
#   Havant                                             | CRS: HAV  | STANOX: 86341  | TIPLOC: HAVANT
#   Hemel Hempstead                                    | CRS: HML  | STANOX: 71011  | TIPLOC: HEMLHMP
#   Herne Hill                                         | CRS: HNH  | STANOX: 87249  | TIPLOC: HERNEH
#   Hersham                                            | CRS: HER  | STANOX: 86003  | TIPLOC: HERSHAM
#   Hertford North                                     | CRS: HFN  | STANOX: 53241  | TIPLOC: HFDN
#   Highams Park                                       | CRS: HIP  | STANOX: 52732  | TIPLOC: HGHMSPK
#   Highbury & Islington                               | CRS: HII  | STANOX: 52053  | TIPLOC: HIGHBYA
#   Highbury&Islington                                 | CRS: HHY  | STANOX: 54293  | TIPLOC: HGHI
#   Hitchin                                            | CRS: HIT  | STANOX: 53221  | TIPLOC: HITCHIN
#   Hither Green                                       | CRS: HGR  | STANOX: 88451  | TIPLOC: HTHRGRN
#   Horsham                                            | CRS: HRH  | STANOX: 87941  | TIPLOC: HORSHAM
#   Hove                                               | CRS: HOV  | STANOX: 88103  | TIPLOC: HOVE
#   Huntingdon                                         | CRS: HUN  | STANOX: 45201  | TIPLOC: HNTNGDN
#   Ilford                                             | CRS: IFD  | STANOX: 50423  | TIPLOC: ILFORD
#   Keighley                                           | CRS: KEI  | STANOX: 17011  | TIPLOC: KEIGHLY
#   Kelvedon                                           | CRS: KEL  | STANOX: 50113  | TIPLOC: KELVEDN
#   Kettering                                          | CRS: KET  | STANOX: 61009  | TIPLOC: KETR
#   Kingham                                            | CRS: KGM  | STANOX: 74465  | TIPLOC: KINGHAM
#   Laindon                                            | CRS: LAI  | STANOX: 51301  | TIPLOC: LAINDON
#   Leatherhead                                        | CRS: LHD  | STANOX: 87685  | TIPLOC: LETHRHD
#   Leigh-On-Sea                                       | CRS: LES  | STANOX: 51013  | TIPLOC: LHONSEA
#   Leighton Buzzard                                   | CRS: LBZ  | STANOX: 70321  | TIPLOC: LTNBZRD
#   Lewes                                              | CRS: LWS  | STANOX: 88221  | TIPLOC: LEWES
#   Lewisham                                           | CRS: LEW  | STANOX: 88415  | TIPLOC: LEWISHM
#   Llandudno Junction                                 | CRS: LLJ  | STANOX: 40050  | TIPLOC: LANDUDJ
#   Malton                                             | CRS: MLT  | STANOX: 16232  | TIPLOC: MALTON
#   Manor Park                                         | CRS: MNP  | STANOX: 50431  | TIPLOC: MANRPK
#   Meadowhall                                         | CRS: MHS  | STANOX: 25316  | TIPLOC: MEADWHL
#   Milford                                            | CRS: MLF  | STANOX: 87059  | TIPLOC: MLFORD
#   Mortlake                                           | CRS: MTL  | STANOX: 87139  | TIPLOC: MRTLKE
#   Motspur Park                                       | CRS: MOT  | STANOX: 87301  | TIPLOC: MOTSPRP
#   New Cross                                          | CRS: NWX  | STANOX: 88410  | TIPLOC: NWCROSS
#   New Eltham                                         | CRS: NEH  | STANOX: 88459  | TIPLOC: NWELTHM
#   New Malden                                         | CRS: NEM  | STANOX: 87169  | TIPLOC: NEWMLDN
#   New Milton                                         | CRS: NWM  | STANOX: 86911  | TIPLOC: NMILTON
#   Norbiton                                           | CRS: NBT  | STANOX: 87163  | TIPLOC: NRBITON
#   Norbury                                            | CRS: NRB  | STANOX: 87633  | TIPLOC: NORBURY
#   Norwood Fork Junction                              | CRS: N/A  | STANOX: 87640  | TIPLOC: NORWDFJ
#   Norwood Junction                                   | CRS: NWD  | STANOX: 87643  | TIPLOC: NORWDJ
#   Ockley                                             | CRS: OLY  | STANOX: 87938  | TIPLOC: OCKLYAC
#   Orpington                                          | CRS: ORP  | STANOX: 88491  | TIPLOC: ORPNGTN
#   Oxted                                              | CRS: OXT  | STANOX: 87751  | TIPLOC: OXTED
#   Paddock Wood                                       | CRS: PDW  | STANOX: 89331  | TIPLOC: PKWD
#   Paignton                                           | CRS: PGN  | STANOX: 83631  | TIPLOC: PAIGNTN
#   Palmers Green                                      | CRS: PAL  | STANOX: 53307  | TIPLOC: PALMRSG
#   Petersfield                                        | CRS: PTR  | STANOX: 87066  | TIPLOC: PTRSFLD
#   Petts Wood                                         | CRS: PET  | STANOX: 88492  | TIPLOC: PETSWD
#   Pitsea                                             | CRS: PSE  | STANOX: 51016  | TIPLOC: PITSEA
#   Ponders End                                        | CRS: PON  | STANOX: 51918  | TIPLOC: PNDRSEN
#   Pontypridd                                         | CRS: PPD  | STANOX: 78215  | TIPLOC: PTYPRID
#   Potters Bar                                        | CRS: PBR  | STANOX: 54001  | TIPLOC: POTRSBR
#   Purley                                             | CRS: PUR  | STANOX: 87801  | TIPLOC: PURLEY
#   Queen's Park (Greater London)                      | CRS: QPW  | STANOX: 72311  | TIPLOC: QPRK
#   Queen's Park (Strathclyde)                         | CRS: QPK  | STANOX: 7575   | TIPLOC: QUNPARK
#   Rainham (Greater London)                           | CRS: RNM  | STANOX: 51347  | TIPLOC: RNHAME
#   Rayleigh                                           | CRS: RLG  | STANOX: 50321  | TIPLOC: RAYLEGH
#   Raynes Park                                        | CRS: RAY  | STANOX: 87271  | TIPLOC: RAYNSPK
#   Retford                                            | CRS: RET  | STANOX: 23491  | TIPLOC: RTFD
#   Rochdale                                           | CRS: RCD  | STANOX: 31033  | TIPLOC: RCHDALE
#   Rochford                                           | CRS: RFD  | STANOX: 50316  | TIPLOC: ROCHFD
#   Romford                                            | CRS: RMF  | STANOX: 50401  | TIPLOC: ROMFORD
#   Salford Crescent                                   | CRS: SLD  | STANOX: 31521  | TIPLOC: SLFDCT
#   Seven Kings                                        | CRS: SVK  | STANOX: 50417  | TIPLOC: SVNKNGS
#   Sidcup                                             | CRS: SID  | STANOX: 88461  | TIPLOC: SIDCUP
#   Sittingbourne                                      | CRS: SIT  | STANOX: 89144  | TIPLOC: STNGBRN
#   South Woodham Ferrers                              | CRS: SOF  | STANOX: 50308  | TIPLOC: WDHAMFR
#   St Austell                                         | CRS: SAU  | STANOX: 85303  | TIPLOC: STAUSTL
#   St Margarets (Greater London)                      | CRS: SMG  | STANOX: 87133  | TIPLOC: STMGTS
#   St Margarets (Hertfordshire)                       | CRS: SMT  | STANOX: 51711  | TIPLOC: SMARGRT
#   St Mary Cray                                       | CRS: SMY  | STANOX: 88493  | TIPLOC: STMRYC
#   Staines                                            | CRS: SNS  | STANOX: 87114  | TIPLOC: STAINES
#   Stanley (Perth)                                    | CRS: N/A  | STANOX: 3110   | TIPLOC: STNY
#   Staplehurst                                        | CRS: SPU  | STANOX: 89326  | TIPLOC: SPHS
#   Stoneleigh                                         | CRS: SNL  | STANOX: 87303  | TIPLOC: STLEIGH
#   Strawberry Hill                                    | CRS: STW  | STANOX: 87134  | TIPLOC: STRWBYH
#   Streatham Common                                   | CRS: SRC  | STANOX: 87631  | TIPLOC: STRHCOM
#   Streatham Hill                                     | CRS: SRH  | STANOX: 87621  | TIPLOC: STRHILL
#   Strines                                            | CRS: SRN  | STANOX: 32554  | TIPLOC: STRINES
#   Sunderland                                         | CRS: SUN  | STANOX: 14031  | TIPLOC: SNDRLND
#   Sunningdale                                        | CRS: SNG  | STANOX: 87104  | TIPLOC: SUNNGDL
#   Sutton (Surrey)                                    | CRS: SUO  | STANOX: 87671  | TIPLOC: SUTTON
#   Swanley                                            | CRS: SAY  | STANOX: 88486  | TIPLOC: SWLY
#   Tadworth                                           | CRS: TAD  | STANOX: 87708  | TIPLOC: TADWTH
#   Tadworth (The Avenue)                              | CRS: TTA  | STANOX:        | TIPLOC: TADWBUS
#   Tamworth                                           | CRS: TAM  | STANOX: 69001  | TIPLOC: TMWTHLL
#   Teddington                                         | CRS: TED  | STANOX: 87159  | TIPLOC: TEDNGTN
#   Telford Central                                    | CRS: TFC  | STANOX: 64827  | TIPLOC: TELFRDC
#   Thornton Heath                                     | CRS: TTH  | STANOX: 87635  | TIPLOC: THTH
#   Torquay                                            | CRS: TQY  | STANOX: 83628  | TIPLOC: TORQUAY
#   Tring                                              | CRS: TRI  | STANOX: 70411  | TIPLOC: TRING
#   Upminster                                          | CRS: UPM  | STANOX: 51351  | TIPLOC: UPMNSTR
#   Upminster Lt                                       | CRS: ZUM  | STANOX: 51353  | TIPLOC: UPMNLT
#   Wallington                                         | CRS: WLT  | STANOX: 87663  | TIPLOC: WALNGTN
#   Walthamstow Central                                | CRS: WHC  | STANOX: 52733  | TIPLOC: WLTWCEN
#   Walton (Merseyside)                                | CRS: WAO  | STANOX: 36029  | TIPLOC: WALTONM
#   Wanborough                                         | CRS: WAN  | STANOX: 87016  | TIPLOC: WANBRO
#   Wandsworth Town                                    | CRS: WNT  | STANOX: 87153  | TIPLOC: WDWTOWN
#   Warblington                                        | CRS: WBL  | STANOX: 86342  | TIPLOC: WRBLNGT
#   Wareham                                            | CRS: WRM  | STANOX: 86964  | TIPLOC: WARHAM
#   Warnham                                            | CRS: WNH  | STANOX: 87939  | TIPLOC: WARNHAM
#   Watlington                                         | CRS: WTG  | STANOX: 46252  | TIPLOC: WATLGTN
#   Welling                                            | CRS: WLI  | STANOX: 88419  | TIPLOC: WELLING
#   Wellingborough                                     | CRS: WEL  | STANOX: 61100  | TIPLOC: WLNGBRO
#   Wellington                                         | CRS: WLN  | STANOX: 64813  | TIPLOC: WELNGTN
#   Wembley Central                                    | CRS: WMB  | STANOX: 72021  | TIPLOC: WMBY
#   West Byfleet                                       | CRS: WBY  | STANOX: 86023  | TIPLOC: WBYFLET
#   West Croydon                                       | CRS: WCY  | STANOX: 87651  | TIPLOC: WCROYDN
#   Weston-Super-Mare                                  | CRS: WSM  | STANOX: 81911  | TIPLOC: WSMARE
#   Weybridge                                          | CRS: WYB  | STANOX: 86005  | TIPLOC: WEYBDGE
#   Whiston                                            | CRS: WHN  | STANOX: 35437  | TIPLOC: WHISTON
#   Whitton                                            | CRS: WTN  | STANOX: 87126  | TIPLOC: WHTTON
#   Wickford                                           | CRS: WIC  | STANOX: 50324  | TIPLOC: WIKFORD
#   Willington                                         | CRS: WIL  | STANOX: 57604  | TIPLOC: WLNTNON
#   Wilmslow                                           | CRS: WML  | STANOX: 32568  | TIPLOC: WLMSL
#   Witham                                             | CRS: WTM  | STANOX: 50211  | TIPLOC: WITHAME
#   Witham (Som)                                       | CRS: N/A  | STANOX: 82241  | TIPLOC: ESTSOMJ
#   Wokingham                                          | CRS: WKM  | STANOX: 87004  | TIPLOC: WOKNGHM
#   Woolwich Arsenal                                   | CRS: WWA  | STANOX: 88517  | TIPLOC: WOLWCHA
#   Worcester Foregate Street                          | CRS: WOF  | STANOX: 67195  | TIPLOC: WORCSFS
#   Worcester Park                                     | CRS: WCP  | STANOX: 87302  | TIPLOC: WRCSTRP
#
# ====================================================================================================
# DfT Category D: 0 stations
# ====================================================================================================
#   No stations found in category D
#
# ====================================================================================================
# DfT Category E: 0 stations
# ====================================================================================================
#   No stations found in category E
#
# ====================================================================================================
# DfT Category F: 0 stations
# ====================================================================================================
#   No stations found in category F
#
# ====================================================================================================
#
# SUMMARY:
#   Total entries in cleaned file: 4319
#   Stations with DfT category: 373
#   Stations without DfT category: 3946
#
# Category breakdown:
#     A: 20
#     B: 63
#     C1: 95
#     C2: 195
# ====================================================================================================

# %% [markdown]
# ## Investigate Missing Category A Stations
#
# Check why Victoria London, London Bridge, and Waterloo London are not in the final file.

# %%
# Check if the manually added stations are present and why they might be missing
print("Investigating manually added Category A stations:")
print("=" * 100)

# Check the TIPLOCs we added
check_tiplocs = ['LNDNBDG', 'VICTRIA', 'WATRLOO']
check_names = ['London Bridge', 'Victoria London', 'Waterloo London']

for tiploc, name in zip(check_tiplocs, check_names):
    print(f"\n{name} (TIPLOC: {tiploc}):")
    
    # Check if in corrected dataset (before filtering)
    in_corrected = (stations_dft_corrected['tiploc'] == tiploc).any()
    print(f"  - In stations_dft_corrected: {in_corrected}")
    
    if in_corrected:
        station_info = stations_dft_corrected[stations_dft_corrected['tiploc'] == tiploc].iloc[0]
        print(f"    Category: {station_info['dft_category']}")
        print(f"    Description: {station_info['description']}")
        print(f"    CRS: {station_info.get('crs', 'N/A')}")
    
    # Check if TIPLOC is in schedule data
    in_schedule = tiploc in all_tiplocs
    print(f"  - TIPLOC in schedule data: {in_schedule}")
    
    # Check if in filtered dataset (after schedule TIPLOC filtering)
    in_filtered = (stations_dft_corrected_filtered['tiploc'] == tiploc).any()
    print(f"  - In stations_dft_corrected_filtered: {in_filtered}")
    
    # Check if in final dataset
    in_final = (stations_final_corrected['tiploc'] == tiploc).any()
    print(f"  - In stations_final_corrected: {in_final}")

print("\n" + "=" * 100)
print("\nDiagnosis:")
print("If TIPLOC is not in schedule data, it will be filtered out during the")
print("'Filter by schedule TIPLOCs' step, even if manually added.")
# Out:
# Investigating manually added Category A stations:
# ====================================================================================================
#
# London Bridge (TIPLOC: LNDNBDG):
#   - In stations_dft_corrected: False
#   - TIPLOC in schedule data: False
#   - In stations_dft_corrected_filtered: False
#   - In stations_final_corrected: False
#
# Victoria London (TIPLOC: VICTRIA):
#   - In stations_dft_corrected: True
#     Category: A
#     Description: Victoria London
#     CRS: VIC
#   - TIPLOC in schedule data: False
#   - In stations_dft_corrected_filtered: False
#   - In stations_final_corrected: False
#
# Waterloo London (TIPLOC: WATRLOO):
#   - In stations_dft_corrected: False
#   - TIPLOC in schedule data: False
#   - In stations_dft_corrected_filtered: False
#   - In stations_final_corrected: False
#
# ====================================================================================================
#
# Diagnosis:
# If TIPLOC is not in schedule data, it will be filtered out during the
# 'Filter by schedule TIPLOCs' step, even if manually added.
